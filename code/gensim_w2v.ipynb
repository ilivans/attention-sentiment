# %%
import cPickle
import gensim

# %%
with open("../data/w2v/word2vec_normalize.bin", "rb") as f:
    binary = f.read()

# %%
with open("dump.txt", "w") as fout:
    fout.write(binary)

# %%
print binary.decode("ISO 8859-5")[:500]
# Out:
# 23446 200
# аНаЕ 47	О%R5>­?VзD>)х,НЏ§?,№?Ч&вОр=йд?Я{ЛП\
# ?5RоОЌОќГG>ЛОЫ?,­:П4є=
# ђ
# п>Fu?ў{>НВ?ќОХ?Ћ

# %%
model = gensim.models.Word2Vec.load_word2vec_format("../data/w2v/word2vec_normalize.bin", binary=True)

# %%
model.save_word2vec_format('../data/w2v/parkin_vectors.txt', binary=False)

# %%
for w in model.vocab.keys():
    print w
# Out:
# гольфстрим
# занятный
# сельдереевый
# нормальный
# тунисский
# francesco
# организм
# небесный
# манагер
# наготове
# выдерживаться
# олигарх
# долететь
# манера
# томный
# система
# удочка
# стеснительный
# деликатный
# шарфик
# результат
# уместный
# зацепить
# владелица
# любоваться
# прогрессировать
# меркурий
# поспособствовать
# разборчиво
# склероз
# графин
# стейковый
# кумар
# фламан
# тайный
# торговать
# гарантировать
# пущать
# францискайнер
# табаско
# неизбежный
# выговор
# мясо
# грейп
# дурной
# скопом
# зачерпнуть
# апокалипсис
# лейтенант
# кусище
# денюжка
# заказчик
# глючить
# пуговка
# music
# слух
# противно
# вороватый
# свалка
# глядеть
# вымучить
# погодить
# изнасиловать
# нелюбовь
# надругательство
# ажурный
# врятлить
# самолепной
# остервенение
# меренгата
# чудовище
# вальполичелла
# нетипичный
# насоветовать
# тянущий
# злить
# относить
# засадить
# акцент
# пивнушка
# сбивчивый
# пшённый
# рассказывать
# депрессивный
# носить
# перепечатать
# ...
