# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# # Banks

# %% [markdown]
# ### Bi-RNN

# %%
results = [[0.89189196, 0.713312971109928],
 [0.90680337, 0.7386951115764675],
 [0.90773529, 0.7318109399893786],
 [0.88723212, 0.7189406150248097],
 [0.89655173, 0.7528973409789262],
 [0.89458948, 0.7461883715352726],
 [0.90205216, 0.7459313081481084],
 [0.89085823, 0.7508561854781087],
 [0.90391797, 0.7795138888888888],
 [0.90111941, 0.7761018399657682]]
print np.mean(np.array(results), axis=0)
print np.std(np.array(results), axis=0)
# Out:
# [ 0.89827517  0.74542486]
# [ 0.00671327  0.02037776]

# %%
results_full = [[0.88621908, 0.7443627450980392],
 [0.88268548, 0.723416509481505],
 [0.88056529, 0.7062681334622825],
 [0.88684577, 0.7343464331840521],
 [0.88543141, 0.7476149771801015],
 [0.90240455, 0.7729938124002149],
 [0.85572845, 0.6985065638925689],
 [0.87906647, 0.7193614471802405],
 [0.88260257, 0.7367416389035846],
 [0.87835932, 0.7331823136459684]]
print np.mean(np.array(results_full), axis=0)
print np.std(np.array(results_full), axis=0)
# Out:
# [ 0.88199084  0.73167946]
# [ 0.01088277  0.02030484]

# %%
plt.plot([1]*10 + [2]*10, [r[1] for r in results] + [r[1] for r in results_full], 'ro')
plt.xlim(0,3)
plt.xticks(range(4), ('', 'train', 'train + test', ''))
plt.ylim(0.65,0.8)
plt.ylabel('F1-score')
plt.title('Bi-RNN, 100 epocs, 10-fold CV')
plt.show()

# %%
# 50 epochs
results = [
 [0.88717949, 0.7170329670329672],
 [0.89417255, 0.6995493099683676],
 [0.88717949, 0.7073619469786554],
 [0.89463866, 0.7190786291909887],
 [0.88857818, 0.7270880690097337]]
print np.mean(np.array(results), axis=0)
print np.std(np.array(results), axis=0)
# Out:
# [ 0.89034967  0.71402218]
# [ 0.00335405  0.00958303]

# %%
results_full = [
 [0.87875587, 0.7104100982386307],
 [0.8762815, 0.6987431635776724],
 [0.88335103, 0.7374117238845572],
 [0.86987281, 0.6918273803027704],
 [0.87199444, 0.7257127257127256]]
print np.mean(np.array(results_full), axis=0)
print np.std(np.array(results_full), axis=0)
# Out:
# [ 0.87605113  0.71282102]
# [ 0.00480178  0.01682635]

# %%
# 100 epochs
results = [[0.89324015, 0.7164872172548044],
 [0.88391614, 0.7252424822889112],
 [0.88251752, 0.7354097811990127],
 [0.89510489, 0.7439244234050753],
 [0.90163177, 0.7809347082092537]]
print np.mean(np.array(results), axis=0)
print np.std(np.array(results), axis=0)
# Out:
# [ 0.89128209  0.74039972]
# [ 0.00716434  0.02227985]

# %%
# full 100 epochs
results_full = [
 [0.87734187, 0.7267407868138702],
 [0.88370454, 0.7187805196902467],
 [0.88971376, 0.7428686960686552],
 [0.86810482, 0.7011658359381601],
 [0.87800574, 0.7338437652263965]]
print np.mean(np.array(results_full), axis=0)
print np.std(np.array(results_full), axis=0)
# Out:
# [ 0.87937415  0.72467992]
# [ 0.0071925   0.01418993]

# %%
plt.plot([1]*5 + [2]*5, [r[1] for r in results] + [r[1] for r in results_full], 'ro')
plt.xlim(0,3)
plt.xticks(range(4), ('', 'train', 'train + test', ''))
plt.ylim(0.65,0.8)
plt.ylabel('F1-score')
plt.title('Bi-RNN, 100 epocs, 5-fold CV')
plt.show()

# %% [markdown]
# ### Bi-RNN + Attention

# %%
# 50 epochs
results50 = [[0.88624716, 0.6608807082945014],
 [0.88857812, 0.6414170142839084],
 [0.8853147, 0.6746440306681271],
 [0.87785548, 0.6531421660646879],
 [0.88018656, 0.6790827581299367]]
print np.mean(np.array(results50), axis=0)
print np.std(np.array(results50), axis=0)
# Out:
# [ 0.8836364   0.66183334]
# [ 0.00398431  0.01381974]

# %%
# full, 100 epochs
results_full  = [[0.88123024, 0.7191655062148641],
 [0.87981623, 0.7126029991986288],
 [0.87804884, 0.7272750818640963],
 [0.86350793, 0.6945751542027747],
 [0.87057996, 0.724006556228417]]
print np.mean(np.array(results_full), axis=0)
print np.std(np.array(results_full), axis=0)
# Out:
# [ 0.87463664  0.71552506]
# [ 0.00666711  0.01158178]

# %%
# 100 epochs
results = [[0.89790213, 0.7224749772520473],
 [0.90069938, 0.7071403812824957],
 [0.8969698, 0.7326181081113496],
 [0.89044285, 0.7287118977384464],
 [0.89603734, 0.7420627309575869]]
print np.mean(np.array(results), axis=0)
print np.std(np.array(results), axis=0)
# Out:
# [ 0.8964103   0.72660162]
# [ 0.00336703  0.01162296]

# %%
plt.plot([1]*5 + [2]*5, [r[1] for r in results] + [r[1] for r in results_full], 'ro')
plt.xlim(0,3)
plt.xticks(range(4), ('', 'train', 'train + test', ''))
plt.ylim(0.65,0.78)
plt.ylabel('F1-score')
plt.title('Bi-RNN + Attention, 100 epocs, 5-fold CV')
plt.show()

# %% [markdown]
# ---

# %% [markdown]
# # TTK

# %%
results = [[0.77307278, 0.630138419973409],
 [0.75298589, 0.6101334246940368],
 [0.76167208, 0.6023446536956889],
 [0.75352883, 0.6297456761082081],
 [0.74144495, 0.620275235600313]]
print np.mean(np.array(results), axis=0)
print np.std(np.array(results), axis=0)
# Out:
# [ 0.75654091  0.61852748]
# [ 0.01048075  0.01091843]

# %%
results_full = [[0.75192797, 0.6311565586613852],
 [0.74978572, 0.6227644278752718],
 [0.7549271, 0.617293799186132],
 [0.7399314, 0.6153623024424364],
 [0.74967849, 0.6353495007132668]]
print np.mean(np.array(results_full), axis=0)
print np.std(np.array(results_full), axis=0)
# Out:
# [ 0.74925014  0.62438532]
# [ 0.00503404  0.00775106]

# %%
results = [[0.78393048, 0.6622562277580072],
 [0.76764387, 0.648942701020526],
 [0.77198702, 0.6450351333347659],
 [0.7752443, 0.6075016450976091],
 [0.77307284, 0.6530045081622938],
 [0.78175896, 0.6344142259414226],
 [0.78393054, 0.673963351623561],
 [0.78393054, 0.682370764512434],
 [0.76330078, 0.6772007579407138],
 [0.76847827, 0.6736971078874605]]
print np.mean(np.array(results), axis=0)
print np.std(np.array(results), axis=0)
# Out:
# [ 0.77532776  0.65583864]
# [ 0.00728176  0.02194694]

# %%
results_full = [[0.77977717, 0.6799574694311536],
 [0.77634954, 0.6410614587670638],
 [0.74978578, 0.6254647887323944],
 [0.77035135, 0.6592200941210425],
 [0.76863754, 0.6453761365455939],
 [0.78320479, 0.6268965517241379],
 [0.7720651, 0.6406979571984435],
 [0.77206504, 0.6509925518652304],
 [0.76778054, 0.6623666958702155],
 [0.76758146, 0.6514228539477943]]
print np.mean(np.array(results_full), axis=0)
print np.std(np.array(results_full), axis=0)
# Out:
# [ 0.77075983  0.64834566]
# [ 0.00856972  0.01560317]

# %%
plt.plot([1]*10 + [2]*10, [r[1] for r in results] + [r[1] for r in results_full], 'ro')
plt.xlim(0,3)
plt.xticks(range(4), ('', 'train', 'train + test', ''))
plt.ylim(0.58,0.72)
plt.ylabel('F1-score')
plt.title('Bi-RNN, 100 epocs, 10-fold CV')
plt.show()

# %% [markdown]
# ### Bi-RNN + Attention

# %%
# 100 epochs
results = [[0.7752443, 0.6444354824569094],
 [0.74104238, 0.5871319212886864],
 [0.77144414, 0.6161357349548102],
 [0.76438653, 0.651841537513209],
 [0.73221081, 0.6246097912413737]]
print np.mean(np.array(results), axis=0)
print np.std(np.array(results), axis=0)
# Out:
# [ 0.75686563  0.62483089]
# [ 0.01711787  0.02285074]

# %%
results = [[0.74538541, 0.5815656570500217],
 [0.73235619, 0.575230172363875],
 [0.76221496, 0.6038730324054631],
 [0.74158525, 0.6319062342251388],
 [0.738729, 0.6132597981270901]]
print np.mean(np.array(results), axis=0)
print np.std(np.array(results), axis=0)
# Out:
# [ 0.74405416  0.60116698]
# [ 0.01002878  0.02076242]

# %%
results_full = [[0.75792623, 0.6166985275710613],
 [0.75535548, 0.6236201314585024],
 [0.73950291, 0.615306136473444],
 [0.74850035, 0.6253543834669906],
 [0.75482213, 0.632388431584852]]
print np.mean(np.array(results_full), axis=0)
print np.std(np.array(results_full), axis=0)
# Out:
# [ 0.75122142  0.62267352]
# [ 0.00662929  0.00620389]

# %%
# 50 epochs
results = [[0.75732905, 0.6225804683789412],
 [0.73778504, 0.5894702108157653],
 [0.76927257, 0.6136263736263736],
 [0.74972856, 0.6020439121092857],
 [0.74579036, 0.6158052450841007]]
print np.mean(np.array(results), axis=0)
print np.std(np.array(results), axis=0)
# Out:
# [ 0.75198112  0.60870524]
# [ 0.01070068  0.01167484]

# %% [markdown]
# ---

# %% [markdown]
# ----

# %% [markdown]
# # Reviews

# %% [markdown]
# ### Bi-RNN

# %%
# layers 2, hid 200, ep 10, mom 0.1
results = np.array([[0.89577414772727271, 0.84676924648528151],
 [0.8984375, 0.85296649931538115],
 [0.86594460227272729, 0.81406281982713646],
 [0.89115767045454541, 0.82949057557529504],
 [0.890625, 0.83799862192138663],
 [0.88707386363636365, 0.81178903695857096],
 [0.88192471590909094, 0.81625233316333656],
 [0.88512073863636365, 0.84057747126195392],
 [0.892578125, 0.84661574055004973],
 [0.89559659090909094, 0.84442664288448399]])
print results.mean(axis=0)
print results.std(axis=0)
# Out:
# [ 0.8884233  0.8340949]
# [ 0.00891972  0.01440815]

# %%
# layers 2, hid 200, ep 10, mom 0.1
results = np.array([[0.89364346590909094, 0.84838915317824726],
 [0.86772017045454541, 0.82466004754000077],
 [0.88068181818181823, 0.80875005836485037],
 [0.87322443181818177, 0.82529168537029529],
 [0.89417613636363635, 0.84259634401438144],
 [0.89186789772727271, 0.83682727050730721],
 [0.88547585227272729, 0.83981214756999001],
 [0.89630681818181823, 0.84910311198038768],
 [0.89612926136363635, 0.84853794515872116],
 [0.87979403409090906, 0.83968741926010138]])
print results.mean(axis=0)
print results.std(axis=0)
# Out:
# [ 0
])
print results.mean(axis=0)
print results.std(axis=0)
# Out:
# [ 0.90310724  0.85912116]
# [ 0.00406062  0.00662582]
# [ 0.90431463  0.85925025]
# [ 0.00437125  0.00777412]

# %% [markdown]
# ### Bi-RNN + Attention

# %%
# layers 2, hid 200, att 100, ep 10, mom 0.1
results_att = np.array([[0.89044744318181823, 0.83040965439956405],
 [0.87677556818181823, 0.78583584778168558],
 [0.88512073863636365, 0.82642950901835355],
 [0.88831676136363635, 0.81978924792555785],
 [0.88760653409090906, 0.81440752811629724],
 [0.892578125, 0.83769683609907863],
 [0.88991477272727271, 0.84465400209557651],
 [0.89488636363636365, 0.83722797644154912],
 [0.89115767045454541, 0.81839138033221026],
 [0.86700994318181823, 0.76159868441985512]])
print results_att.mean(axis=0)
print results_att.std(axis=0)
# Out:
# [ 0.88638139  0.81764407]
# [ 0.00798076  0.02433887]

# %%
# hid 200, att 100, ep 10, mom 0.1
results_att = np.array([[0.89488636363636365, 0.84211754508784209],
 [0.89240056818181823, 0.83337863804658574],
 [0.87375710227272729, 0.78396033549672317],
 [0.89328835227272729, 0.83876991486867147],
 [0.88742897727272729, 0.82044053090281799],
 [0.88387784090909094, 0.80660705464883009],
 [0.884765625, 0.81650946358517817],
 [0.884765625, 0.80772594752953397],
 [0.89488636363636365, 0.8356066365899959],
 [0.88973721590909094, 0.82726533023206883]])
print results_att.mean(axis=0)
print results_att.std(axis=0)
# Out:
# [ 0.8879794   0.82123814]
# [ 0.00621522  0.01715449]

# %%
# hid 300, att 100, ep 20, mom 0.1
results_att = np.array([[0.8984375, 0.8456319971049866],
 [0.90216619318181823, 0.85775310250843251],
 [0.88796164772727271, 0.83567111861850241],
 [0.89506392045454541, 0.84517551479479014],
 [0.89115767045454541, 0.84229205535978169],
 [0.89026988636363635, 0.82472930194183913],
 [0.89453125, 0.84119191133579618],
 [0.89719460227272729, 0.85409524233946188],
 [0.89932528409090906, 0.83969316772387659],
 [0.90003551136363635, 0.85215848318017495]])
print results_att.mean(axis=0)
print results_att.std(axis=0)
# Out:
# [ 0.89561435  0.84383919]
# [ 0.00441788  0.00911861]

# %%
# hid 100, att 100, ep 20, Momentum 0.1
results_att = np.array([[0.89453125, 0.83472022955523673],
 [0.88263494318181823, 0.80009132080241807],
 [0.88973721590909094, 0.82726533023206872],
 [0.88742897727272729, 0.81725631859116521],
 [0.89328835227272729, 0.83723951439862265],
 [0.89577414772727271, 0.84819626582128804],
 [0.87748579545454541, 0.79626605197530842],
 [0.88778409090909094, 0.81226904300789449],
 [0.90021306818181823, 0.8481388616210439],
 [0.89044744318181823, 0.85117996914343597]])
print results_att.mean(axis=0)
print results_att.std(axis=0)
# Out:
# [ 0.88993253  0.82726229]
# [ 0.00625769  0.01904003]

# %%
# hid 600, att 100, ep 10, Momentum 0.1
results_att = np.array([[0.890625, 0.8268521263481512],
 [0.89524147727272729, 0.84630342455552199],
 [0.88192471590909094, 0.80616482273066903],
 [0.88725142045454541, 0.81972026375146401],
 [0.88991477272727271, 0.83465013167983471],
 [0.89115767045454541, 0.82572377629243543],
 [0.88938210227272729, 0.84527591928078105],
 [0.88778409090909094, 0.81678319288213119],
 [0.89825994318181823, 0.84871638189089049],
 [0.89666193181818177, 0.85305718435633981]])
print results_att.mean(axis=0)
print results_att.std(axis=0)
# Out:
# [ 0.89082031  0.83232472]
# [ 0.00461678  0.01491757]

# %%
# hid 600, att 100, ep 15, Momentum 0.1
results_att = np.array([[0.89115767045454541, 0.82692629206739654],
 [0.89275568181818177, 0.8260277559570568],
 [0.89169034090909094, 0.8368130823133676],
 [0.89222301136363635, 0.82944006633560408],
 [0.890625, 0.83520796509022044],
 [0.89683948863636365, 0.8409279539737069],
 [0.88636363636363635, 0.8198601253214749],
 [0.90198863636363635, 0.85662337662337662],
 [0.89825994318181823, 0.84008099182276941],
 [0.88547585227272729, 0.81171981733612952]])
print results_att.mean(axis=0)
print results_att.std(axis=0)
# Out:
# [ 0.89273793  0.83236274]
# [ 0.0048434   0.01187471]

# %%
# hid 50, att 100, ep 20, Momentum 0.1
results_att = np.array([[0.89009232954545459, 0.82677570765180852],
 [0.89630681818181823, 0.83804409376548006],
 [0.89026988636363635, 0.83891460480628899],
 [0.89382102272727271, 0.83800046445880061],
 [0.89364346590909094, 0.84059440667986463],
 [0.89541903409090906, 0.83703658071025822],
 [0.89541903409090906, 0.85189941431646554],
 [0.88174715909090906, 0.79627363737486112],
 [0.89506392045454541, 0.8294677707544813],
 [0.89719460227272729, 0.85496610619606395]])
print results_att.mean(axis=0)
print results_att.std(axis=0)
# Out:
# [ 0.89289773  0.83519728]
# [ 0.00433602  0.01533252]

# %%
# hid 25, att 100, ep 20, Momentum 0.1
results_att = np.array([[0.88441051136363635, 0.81147913596043675],
 [0.8984375, 0.84158263155731028],
 [0.89151278409090906, 0.82843307283335021],
 [0.89186789772727271, 0.83161452625949206],
 [0.88245738636363635, 0.80246310763888884],
 [0.88494318181818177, 0.80780586450960568],
 [0.89382102272727271, 0.84100690991057503],
 [0.892578125, 0.82751686519029888],
 [0.89612926136363635, 0.82771825781636021],
 [0.89595170454545459, 0.84284298526862522]])
print results_att.mean(axis=0)
print results_att.std(axis=0)
# Out:
# [ 0.89121094  0.82624634]
# [ 0.00519853  0.01374652]

# %%
# hid 10, att 100, ep 20, Momentum 0.1
results_att = np.array([[0.89790482954545459, 0.84954591755549291],
 [0.90056818181818177, 0.8503746421756857],
 [0.88849431818181823, 0.81950099769840423],
 [0.88902698863636365, 0.82280548749255922],
 [0.89311079545454541, 0.84308510047473462],
 [0.888671875, 0.81777182723625019],
 [0.86257102272727271, 0.75959800644444431],
 [0.89932528409090906, 0.85758637450445463],
 [0.89559659090909094, 0.82916852374585248],
 [0.89577414772727271, 0.85429389293211344]])
print results_att.mean(axis=0)
print results_att.std(axis=0)
# Out:
# [ 0.8911044   0.83037308]
# [ 0.0103952   0.02754423]

# %%
# hid 300, att 100, ep 30, mom 0.1
results_att = np.array([[0.89151278409090906, 0.82889864271055136],
 [0.90305397727272729, 0.85818181818181816],
 [0.88405539772727271, 0.83257549805281228],
 [0.89701704545454541, 0.84541317391566895],
 [0.88618607954545459, 0.84172561254781453],
 [0.89683948863636365, 0.84051325204957938],
 [0.89790482954545459, 0.85112704011327289],
 [0.90411931818181823, 0.85580763427572704],
 [0.90340909090909094, 0.8570195481086571],
 [0.89825994318181823, 0.84492091756623067]])
print results_att.mean(axis=0)
print results_att.std(axis=0)
# Out:
# [ 0
])
print results_att.mean(axis=0)
print results_att.std(axis=0)
# Out:
# [ 0.89824219  0.84863934]
# [ 0.00393716  0.00818796]

# %%
# hid 300, att 150 relu, ep 40, mom 0.1, max_val_f
results_att = np.array([[0.90026041666666667, 0.85514644665483641],
 [0.89409722222222221, 0.84247826700292483],
 [0.89704861111111112, 0.84822108084091086],
 [0.90407986111111116, 0.85970258062453353],
 [0.90190972222222221, 0.85642122454354119]])
print results_att.mean(axis=0)
print results_att.std(axis=0)
# Out:
# [ 0.89947917  0.85239392]
# [ 0.00353715  0.006212  ]

# %%
# hid 300, att 150 relu, ep 20, mom 0.1, max_val_f
results_att = np.array([[0.89722222222222225, 0.84830074384650456],
 [0.8911458333333333, 0.84057959755035561],
 [0.89461805555555551, 0.845801200474398],
 [0.89644097222222219, 0.85441890061718195],
 [0.90104166666666663, 0.85702331174979918]])
print results_att.mean(axis=0)
print results_att.std(axis=0)
# Out:
# [ 0.89609375  0.84922475]
# [ 0.00324146  0.00591794]

# %%
# hid 300, att 20 relu, ep 10, Adam 1e-3, max_val_f
results_att = np.array([[0.90518465909090906, 0.86056321650856504],
 [0.90465198863636365, 0.86527668990291917],
 [0.89666193181818177, 0.84546548576090252],
 [0.89932528409090906, 0.8462959876427002],
 [0.89897017045454541, 0.84959054759257935],
 [0.90518465909090906, 0.85956374043185146],
 [0.90358664772727271, 0.86203237605330252],
 [0.90909090909090906, 0.86943014791116058],
 [0.90926846590909094, 0.86428741934196451],
 [0.90323153409090906, 0.86167372432131706]])
print results_att.mean(axis=0)
print results_att.std(axis=0)

results_att = np.array([[0.90873579545454541, 0.86610162749413266],
 [0.91086647727272729, 0.86953411924880086],
 [0.89488636363636365, 0.84473691894119796],
 [0.90056818181818177, 0.85117658751251701],
 [0.89932528409090906, 0.85202867544946137],
 [0.90518465909090906, 0.86305702427121167],
 [0.90802556818181823, 0.87076874227458811],
 [0.90607244318181823, 0.86319561263962763],
 [0.90873579545454541, 0.86436267965996139],
 [0.90340909090909094, 0.86385022069381356]])
print results_att.mean(axis=0)
print results_att.std(axis=0)
# Out:
# [ 0.90351563  0.85841793]
# [ 0.00395374  0.00790552]
# [ 0.90458097  0.86088122]
# [ 0.00477043  0.00814924]

# %% [markdown]
# CNN

# %%
results = np.array([[0.90536221590909094, 0.86204278884069963],
 [0.90234375, 0.85367918253824304],
 [0.89701704545454541, 0.84285550523096697],
 [0.90287642045454541, 0.85261131486448871],
 [0.89524147727272729, 0.84816582444319666],
 [0.90056818181818177, 0.85228249474123574],
 [0.90074573863636365, 0.85866966360127295],
 [0.90269886363636365, 0.85747561036658804],
 [0.90607244318181823, 0.85701071648845861],
 [0.90092329545454541, 0.85664716343793257]])
print results.mean(axis=0)
print results.std(axis=0)
# Out:
# [ 0.90138494  0.85414403]
# [ 0.00317445  0.0052693 ]

# %% [markdown]
# # Kinopoisk

# %%
results = np.array([[0.829, 0.650], [0.815, 0.648], [0.823, 0.645], [0.833, 0.676]])
print results.mean(axis=0)
print results.std(axis=0)
# Out:
# [ 0.825    0.65475]
# [ 0.00678233  0.01239708]
